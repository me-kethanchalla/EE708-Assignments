# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("A1.csv")
df
# Out:
#      Sample Number Classes  Feature 1  Feature 2  Feature 3  Feature 4     Sex
# 0                1       A       39.2       18.6        190       4250    MALE
# 1                2       B       45.2       13.8        215       4750  FEMALE
# 2                3       C       51.9       19.5        206       3950    MALE
# 3                4       A       42.8       18.5        195       4250    MALE
# 4                5       B       42.6       13.7        213       4950  FEMALE
# ..             ...     ...        ...        ...        ...        ...     ...
# 337            338       A       40.1       18.9        188       4300    MALE
# 338            339       B       46.8       16.1        215       5500    MALE
# 339            340       B       59.6       17.0        230       6050    MALE
# 340            341       A       42.2       18.5        180       3550  FEMALE
# 341            342       B       47.5       15.0        218       4950  FEMALE
#
# [342 rows x 7 columns]

# %% [markdown]
# # a

# %%
df['Classes'].value_counts()
# Out:
# Classes
# A    151
# B    123
# C     68
# Name: count, dtype: int64

# %% [markdown]
# # b

# %%
des = df.describe()
des
# Out:
#        Sample Number   Feature 1   Feature 2   Feature 3    Feature 4
# count     342.000000  342.000000  342.000000  342.000000   342.000000
# mean      171.500000   43.921930   17.151170  200.915205  4201.754386
# std        98.871128    5.459584    1.974793   14.061714   801.954536
# min         1.000000   32.100000   13.100000  172.000000  2700.000000
# 25%        86.250000   39.225000   15.600000  190.000000  3550.000000
# 50%       171.500000   44.450000   17.300000  197.000000  4050.000000
# 75%       256.750000   48.500000   18.700000  213.000000  4750.000000
# max       342.000000   59.600000   21.500000  231.000000  6300.000000

# %%
print('Inter quartile Range')
print('Feature 1' , des.iloc[6]['Feature 1'] - des.iloc[4]['Feature 1'])
print('Feature 2' , des.iloc[6]['Feature 2'] - des.iloc[4]['Feature 2'])
print('Feature 3' , des.iloc[6]['Feature 3'] - des.iloc[4]['Feature 3'])
print('Feature 4' , des.iloc[6]['Feature 4'] - des.iloc[4]['Feature 4'])
# Out:
# Inter quartile Range
# Feature 1 9.274999999999999
# Feature 2 3.0999999999999996
# Feature 3 23.0
# Feature 4 1200.0

# %% [markdown]
# # c

# %%
df2 = df[df['Classes'] == 'A']
df3 = df[df['Classes'] == 'B']
df4 = df[df['Classes'] == 'C']

plt.hist(df2['Feature 1'])
# Out:
# (array([ 2.,  7., 20., 23., 30., 24., 27., 13.,  2.,  3.]),
#  array([32.1 , 33.49, 34.88, 36.27, 37.66, 39.05, 40.44, 41.83, 43.22,
#         44.61, 46.  ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # d

# %%
fig, ax = plt.subplots(figsize=(8, 6))

ax.boxplot([df2['Feature 2'], df3['Feature 2'], df4['Feature 2']]) 
ax.set_xticklabels(['Class A','Class B','Class C'])
ax.set_ylabel('Frequency')
plt.show()

# %% [markdown]
# # e

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.violinplot([df2['Feature 3'], df3['Feature 3'], df4['Feature 3']])

ax.set_ylabel('Frequency')
plt.show()

# %% [markdown]
# # f

# %%
plt.figure(figsize=(12,6))
plt.scatter(df2['Feature 3'], df2['Feature 1'])
plt.title('Class A')
plt.xlabel('Feature 3')
plt.ylabel('Feature 1')
plt.legend()
plt.show()

plt.figure(figsize=(12,6))
plt.scatter(df3['Feature 3'], df3['Feature 1'])
plt.title('Class B')
plt.xlabel('Feature 3')
plt.ylabel('Feature 1')
plt.legend()
plt.show()

plt.figure(figsize=(12,6))
plt.scatter(df4['Feature 3'], df4['Feature 1'])
plt.title('Class C')
plt.xlabel('Feature 3')
plt.ylabel('Feature 1')
plt.legend()
plt.show()
# Out:
# C:\Users\Kethan Challa\AppData\Local\Temp\ipykernel_29808\326031591.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\Kethan Challa\AppData\Local\Temp\ipykernel_29808\326031591.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\Kethan Challa\AppData\Local\Temp\ipykernel_29808\326031591.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # G

# %%
plt.figure(figsize=(12,6))
x = np.linspace(df2['Feature 4'].min(), df2['Feature 4'].max(), 100)
y = np.linspace(df2['Feature 1'].min(), df2['Feature 1'].max(), 100)
X, Y = np.meshgrid(x, y)
Z = (X * 0.001) + (Y * 0.1) + np.random.randn(*X.shape)  
cp = plt.contour(X, Y, Z)
plt.title('Class A')
plt.xlabel('Feature 4')
plt.ylabel('Feature 1')
plt.colorbar(cp)
plt.show()


plt.figure(figsize=(12,6))
x = np.linspace(df3['Feature 4'].min(), df3['Feature 4'].max(), 100)
y = np.linspace(df3['Feature 1'].min(), df3['Feature 1'].max(), 100)
X, Y = np.meshgrid(x, y)
Z = (X * 0.001) + (Y * 0.1) + np.random.randn(*X.shape)  
cp = plt.contour(X, Y, Z)
plt.title('Class B')
plt.xlabel('Feature 4')
plt.ylabel('Feature 1')
plt.colorbar(cp)
plt.show()

plt.figure(figsize=(12,6))
x = np.linspace(df4['Feature 4'].min(), df4['Feature 4'].max(), 100)
y = np.linspace(df4['Feature 1'].min(), df4['Feature 1'].max(), 100)
X, Y = np.meshgrid(x, y)
Z = (X * 0.001) + (Y * 0.1) + np.random.randn(*X.shape)  
cp = plt.contour(X, Y, Z)
plt.title('Class C')
plt.xlabel('Feature 4')
plt.ylabel('Feature 1')
plt.colorbar(cp)
plt.show()

# %% [markdown]
# # H

# %%
plt.figure ( figsize= (12,6))
plt.hexbin(df2['Feature 2'], df2['Feature 4'])
plt.title('Hexagonal Bin Plot')
plt.xlabel('Feature 2')
plt.ylabel('Feature 4')
plt.colorbar(label='Density')
plt.show()

# %% [markdown]
# # I

# %%
import seaborn as sns
df5 = df.drop(columns = ['Sample Number', 'Classes', 'Sex'])
corr_matrix = df5.corr()

plt.figure(figsize=(12, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # J

# %%
sns.pairplot(df, vars=['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4'], hue="Classes")
plt.show()
